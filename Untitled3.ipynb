# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramith10/Apple-stock-price-prediction-using-ml/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This progra uses an artificial recurrent neural network called Long Short Term Memory(LSTM)

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import yfinance as yf

# %%
df = yf.download('AAPL', start='2016-01-01',  end='2022-12-17')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.009064
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.407413
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.949339
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   21.980774
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.097000
# ...                ...         ...         ...         ...         ...
# 2022-12-12  142.699997  144.500000  141.059998  144.490005  143.876160
# 2022-12-13  149.500000  149.970001  144.240005  145.470001  144.852005
# 2022-12-14  145.350006  146.660004  141.160004  143.210007  142.601608
# 2022-12-15  141.110001  141.800003  136.029999  136.500000  135.920105
# 2022-12-16  136.690002  137.649994  133.729996  134.509995  133.938568
#
#                Volume
# Date
# ...

# %%
df.shape
# Out:
# (1753, 6)

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD($)',fontsize=18)
plt.show()

# %%
data = df.filter(['Close'])
dataset = data.values
training_data_len = math.ceil(len(dataset)* .8)
training_data_len
# Out:
# 1403

# %%
#Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.02353772],
#        [0.01939784],
#        [0.01624589],
#        ...,
#        [0.75662544],
#        [0.71453664],
#        [0.70205425]])

# %%
#Create the training dataset
#Create the scaled dataset
train_data = scaled_data[0:training_data_len,:]
#Split the data into x_train and y_train
x_train=[]
y_train=[]
for i in range(60,len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])
  if i<=61:
    print(x_train)
    print(y_train)
    print()
# Out:
# [array([0.02353772, 0.01939784, 0.01624589, 0.00958131, 0.01038106,
#        0.01284303, 0.01508547, 0.01105536, 0.01439548, 0.01064764,
#        0.00991063, 0.01011448, 0.0093461 , 0.01737494, 0.01427004,
#        0.01513251, 0.00482986, 0.00588051, 0.01097695, 0.00954995,
#        0.00649209, 0.0094245 , 0.00981653, 0.00577074, 0.0073232 ,
#        0.00729183, 0.00616277, 0.00526894, 0.0057237 , 0.00987926,
#        0.0122001 , 0.00928337, 0.00893838, 0.01025561, 0.0068214 ,
#        0.00903246, 0.01006744, 0.01030266, 0.00995767, 0.0159793 ,
#        0.0163243 , 0.0175004 , 0.01986829, 0.01808061, 0.01676337,
#        0.01690451, 0.01698291, 0.01869218, 0.01909989, 0.02233026,
#        0.02450997, 0.02424339, 0.02443155, 0.02441588, 0.02568607,
#        0.02476086, 0.02403952, 0.02328682, 0.02719148, 0.03013957])]
# [0.029245730063327924]
#
# [array([0.02353772, 0.01939784, 0.01624589, 0.00958131, 0.01038106,
#        0.01284303, 0.01508547, 0.01105536, 0.01439548, 0.01064764,
# ...

# %%
#Convert the x_train and y_train to numpy array
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
#Reshape the data
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1343, 60, 1)

# %%
#Build the LSTM model
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
#Compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
#Train the model
model.fit(x_train,y_train,batch_size=1,epochs=1)
# Out:
# 1343/1343 [==============================] - 56s 39ms/step - loss: 0.0011

# %%
#Create the testing dataset
#Create a new array containing scaled values from index 1343 to 1753
test_data = scaled_data[training_data_len-60:,:]
#Create the data sets x_test and y_test
x_test=[]
y_test = dataset[training_data_len:,:]
for i in range(60,len(test_data)) :
  x_test.append(test_data[i-60:i,0])

# %%
#Convert the data to numpy array
x_test = np.array(x_test)

# %%
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
#Get the model's predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 11/11 [==============================] - 1s 20ms/step

# %%
#Get the root mean squared error for evaluation
rmse = np.sqrt(np.mean(predictions-y_test)**2)
rmse
# Out:
# 5.410316336495535

# %%
#plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions']=predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel("Date",fontsize =18)
plt.ylabel('Close Price USD($)',fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train','Val','Predictions'], loc = 'lower right')
plt.show()
# Out:
# <ipython-input-41-1e60f4abdfa4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions']=predictions

# %%
#show the valid and predicted prices
valid
# Out:
#                  Close  Predictions
# Date
# 2021-07-30  145.860001   152.357361
# 2021-08-02  145.520004   152.200836
# 2021-08-03  147.360001   152.012680
# 2021-08-04  146.949997   151.992188
# 2021-08-05  147.059998   152.024628
# ...                ...          ...
# 2022-12-12  144.490005   150.109528
# 2022-12-13  145.470001   149.715820
# 2022-12-14  143.210007   149.608093
# 2022-12-15  136.500000   149.466980
# 2022-12-16  134.509995   148.718369
#
# [350 rows x 2 columns]

# %%
#Get the quote
apple_quote = yf.download('AAPL', start='2016-01-01',  end='2022-12-17')
#Create a new dataframe
new_df = apple_quote.filter(['Close'])
#Get the last 60 day closing prices and onvert the datframe to array
last_60_days = new_df[-60:].values
last_60_days_scaled = scaler.transform(last_60_days)
X_test=[]
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
pred_price=model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1/1 [==============================] - 0s 44ms/step
# [[147.53123]]

# %%
symbol = 'AAPL'

# Replace '2022-12-18' with the specific date you want
#date = '2022-12-23'

# Get the stock data for the specified date
stock_data = yf.download(symbol, start='2022-12-18', end='2022-12-31')

# Print the Close price for the specified date
print(f"Close price for {symbol} on: {stock_data['Close']}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Close price for AAPL on: Date
# 2022-12-19    132.369995
# 2022-12-20    132.300003
# 2022-12-21    135.449997
# 2022-12-22    132.229996
# 2022-12-23    131.860001
# 2022-12-27    130.029999
# 2022-12-28    126.040001
# 2022-12-29    129.610001
# 2022-12-30    129.929993
# Name: Close, dtype: float64
